# %%
# Importing all the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading data from csv using pandas
data=pd.read_csv("covid_vaccine_statewise.csv")

# %%
# First 5 lines of the data 
data.head(5)
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites
# 0  16/01/2021  India                   48276.0    3455.0   2957.0  \
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered
# 0                  48276.0                       0.0  \
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)
# 0                        NaN                          NaN  \
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
# Last 5 lines of the data
data.tail(5)
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN  \
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered
# 7840                      NaN                       NaN  \
# 7841                      NaN                       NaN
# 7842                      NaN                       NaN
# 7843                      NaN                       NaN
# 7844                      NaN                       NaN
#
#       Male (Doses Administered)  Female (Doses Administered)
# 7840                        NaN                          NaN  \
# ...

# %%
#Describing the data
data.describe()
# Out:
#        Total Doses Administered      Sessions        Sites
# count              7.621000e+03  7.621000e+03   7621.000000  \
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered
# count             7.621000e+03              7.621000e+03  \
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
# Showing the Data types of the columns
data.dtypes
# Out:
# Updated On                              object
# State                                   object
# Total Doses Administered               float64
# Sessions                               float64
#  Sites                                 float64
# First Dose Administered                float64
# Second Dose Administered               float64
# Male (Doses Administered)              float64
# Female (Doses Administered)            float64
# Transgender (Doses Administered)       float64
#  Covaxin (Doses Administered)          float64
# CoviShield (Doses Administered)        float64
# Sputnik V (Doses Administered)         float64
# AEFI                                   float64
# 18-44 Years (Doses Administered)       float64
# 45-60 Years (Doses Administered)       float64
# 60+ Years (Doses Administered)         float64
# 18-44 Years(Individuals Vaccinated)    float64
# 45-60 Years(Individuals Vaccinated)    float64
# 60+ Years(Individuals Vaccinated)      float64
# ...

# %%
# Removing all records where state == India as it has discrepency in it
data["State"].unique()
data = data[data['State'] != 'India']

# %%
# Showing the null values
data.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                218
# Sessions                                218
#  Sites                                  218
# First Dose Administered                 218
# Second Dose Administered                218
# Male (Doses Administered)               218
# Female (Doses Administered)             218
# Transgender (Doses Administered)        218
#  Covaxin (Doses Administered)           218
# CoviShield (Doses Administered)         218
# Sputnik V (Doses Administered)         4719
# AEFI                                   2342
# 18-44 Years (Doses Administered)       5977
# 45-60 Years (Doses Administered)       5977
# 60+ Years (Doses Administered)         5977
# 18-44 Years(Individuals Vaccinated)    4001
# 45-60 Years(Individuals Vaccinated)    4000
# 60+ Years(Individuals Vaccinated)      4000
# Male(Individuals Vaccinated)           7633
# ...

# %%
# Filling zeros with NAN and replacing NAN with Mean of the columns

data['First Dose Administered'].replace(0 , np.nan , inplace = True)
data['First Dose Administered'].fillna(data['First Dose Administered'].mean() , inplace = True)
data['Second Dose Administered'].replace(0 , np.nan , inplace = True)
data['Second Dose Administered'].fillna(data['Second Dose Administered'].mean() , inplace = True)
data['Male (Doses Administered)'].replace(0 , np.nan , inplace = True)
data['Male (Doses Administered)'].fillna(data['Male (Doses Administered)'].mean() , inplace = True)
data['Female (Doses Administered)'].replace(0 , np.nan , inplace = True)
data['Female (Doses Administered)'].fillna(data['Female (Doses Administered)'].mean() , inplace = True)
data['Total Doses Administered'].replace(0 , np.nan , inplace = True)
data['Total Doses Administered'].fillna(data['Total Doses Administered'].mean() , inplace  = True)
data.fillna(0 , inplace=True)
data.head()
# Out:
#      Updated On                        State  Total Doses Administered
# 212  16/01/2021  Andaman and Nicobar Islands                      23.0  \
# 213  17/01/2021  Andaman and Nicobar Islands                      23.0
# 214  18/01/2021  Andaman and Nicobar Islands                      42.0
# 215  19/01/2021  Andaman and Nicobar Islands                      89.0
# 216  20/01/2021  Andaman and Nicobar Islands                     124.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered
# 212       2.0      2.0                     23.0              1.056789e+06  \
# 213       2.0      2.0                     23.0              1.056789e+06
# 214       9.0      2.0                     42.0              1.056789e+06
# 215      12.0      2.0                     89.0              1.056789e+06
# 216      16.0      3.0                    124.0              1.056789e+06
#
#      Male (Doses Administered)  Female (Doses Administered)
# ...

# %%
# Dropping columns which are of no use

data = data.drop(['Transgender (Doses Administered)' ,'18-44 Years (Doses Administered)' , '45-60 Years (Doses Administered)' , '60+ Years (Doses Administered)' , '18-44 Years(Individuals Vaccinated)' , '45-60 Years(Individuals Vaccinated)' , '60+ Years(Individuals Vaccinated)' , 'Transgender(Individuals Vaccinated)' , 'Sessions'] , axis = 1)

# %%
# showing null again with zero null values
data.isnull().sum()
# Out:
# Updated On                         0
# State                              0
# Total Doses Administered           0
#  Sites                             0
# First Dose Administered            0
# Second Dose Administered           0
# Male (Doses Administered)          0
# Female (Doses Administered)        0
#  Covaxin (Doses Administered)      0
# CoviShield (Doses Administered)    0
# Sputnik V (Doses Administered)     0
# AEFI                               0
# Male(Individuals Vaccinated)       0
# Female(Individuals Vaccinated)     0
# Total Individuals Vaccinated       0
# dtype: int64

# %%
# First 5 lines of data
data.head()
# Out:
#      Updated On                        State  Total Doses Administered
# 212  16/01/2021  Andaman and Nicobar Islands                      23.0  \
# 213  17/01/2021  Andaman and Nicobar Islands                      23.0
# 214  18/01/2021  Andaman and Nicobar Islands                      42.0
# 215  19/01/2021  Andaman and Nicobar Islands                      89.0
# 216  20/01/2021  Andaman and Nicobar Islands                     124.0
#
#       Sites   First Dose Administered  Second Dose Administered
# 212      2.0                     23.0              1.056789e+06  \
# 213      2.0                     23.0              1.056789e+06
# 214      2.0                     42.0              1.056789e+06
# 215      2.0                     89.0              1.056789e+06
# 216      3.0                    124.0              1.056789e+06
#
#      Male (Doses Administered)  Female (Doses Administered)
# 212                       12.0                         11.0  \
# ...

# %%
# Converting Data type columns into int64

data['Total Doses Administered'] = data['Total Doses Administered'].astype('int64')
data['First Dose Administered'] = data['First Dose Administered'].astype('int64')
data['Second Dose Administered'] = data['Second Dose Administered'].astype('int64')
data['Male (Doses Administered)'] = data['Male (Doses Administered)'].astype('int64')
data['Female (Doses Administered)'] = data['Female (Doses Administered)'].astype('int64')
data[' Covaxin (Doses Administered)'] = data[' Covaxin (Doses Administered)'].astype('int64')
data['CoviShield (Doses Administered)'] = data['CoviShield (Doses Administered)'].astype('int64')
data['Sputnik V (Doses Administered)'] = data['Sputnik V (Doses Administered)'].astype('int64')
data['AEFI'] = data['AEFI'].astype('int64')
data['Male(Individuals Vaccinated)'] = data['Male(Individuals Vaccinated)'].astype('int64')
data['Female(Individuals Vaccinated)'] = data['Female(Individuals Vaccinated)'].astype('int64')
data['Total Individuals Vaccinated'] = data['Total Individuals Vaccinated'].astype('int64')

# %%
# Checking Data types
data.dtypes
# Out:
# Updated On                          object
# State                               object
# Total Doses Administered             int64
#  Sites                             float64
# First Dose Administered              int64
# Second Dose Administered             int64
# Male (Doses Administered)            int64
# Female (Doses Administered)          int64
#  Covaxin (Doses Administered)        int64
# CoviShield (Doses Administered)      int64
# Sputnik V (Doses Administered)       int64
# AEFI                                 int64
# Male(Individuals Vaccinated)         int64
# Female(Individuals Vaccinated)       int64
# Total Individuals Vaccinated         int64
# dtype: object

# %%
# Splitting the updated on date properly and removing the / to convert into columns
date = data['Updated On'].str.split('/', expand=True)
date
# Out:
#        0   1     2
# 212   16  01  2021
# 213   17  01  2021
# 214   18  01  2021
# 215   19  01  2021
# 216   20  01  2021
# ...   ..  ..   ...
# 7840  11  08  2021
# 7841  12  08  2021
# 7842  13  08  2021
# 7843  14  08  2021
# 7844  15  08  2021
#
# [7633 rows x 3 columns]

# %%
# Date is in correct format now

data['day'] = date[0]
data['month'] = date[1]
data['year'] = date[2]

data['day'] = pd.to_numeric(data['day'])
data['month'] = pd.to_numeric(data['month'])
data['year'] = pd.to_numeric(data['year'])

data['Updated On'] = pd.to_datetime(data['Updated On'])
data.rename(columns = {'Updated On' : 'Vaccine_date'}, inplace = True)

data.head()
# Out:
# /tmp/ipykernel_12074/3628968372.py:11: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Updated On'] = pd.to_datetime(data['Updated On'])
#     Vaccine_date                        State  Total Doses Administered
# 212   2021-01-16  Andaman and Nicobar Islands                        23  \
# 213   2021-01-17  Andaman and Nicobar Islands                        23
# 214   2021-01-18  Andaman and Nicobar Islands                        42
# 215   2021-01-19  Andaman and Nicobar Islands                        89
# 216   2021-01-20  Andaman and Nicobar Islands                       124
#
#       Sites   First Dose Administered  Second Dose Administered
# 212      2.0                       23                   1056789  \
# 213      2.0                       23                   1056789
# 214      2.0                       42                   1056789
# ...

# %% [markdown]
# TOTAL MALES VACCINATED

# %%
# Total Number of Male administered doses

number_of_males_vaccinated = data['Male (Doses Administered)'].sum()
males_to_plot = number_of_males_vaccinated
number_of_males_vaccinated = '{:,.0f}'.format(number_of_males_vaccinated)
print('Total Number of Males Vaccinated : ',number_of_males_vaccinated )
# Out:
# Total Number of Males Vaccinated :  17,579,361,605

# %% [markdown]
# TOTAL FEMALE VACCINATED

# %%
# Total Number of Female administered doses

number_of_females_vaccinated = data['Female (Doses Administered)'].sum()
females_to_plot = number_of_females_vaccinated
number_of_females_vaccinated = '{:,.0f}'.format(number_of_females_vaccinated)
print('Total Number of Females Vaccinated : ',number_of_females_vaccinated )
# Out:
# Total Number of Females Vaccinated :  15,419,521,761

# %%
plt.pie([males_to_plot , females_to_plot], labels = ['Males','Females'],
        colors = ['#4f46e5','#ec4899'], autopct = '%0.0f%%', startangle = 90, radius = 2)
plt.legend(loc='best',shadow=True,fontsize=11)
plt.show()

# %%
new_data = data

# %% [markdown]
# STATEWISE TOTAL DOSES ADMINISTERED

# %%
# Statewise vaccination Doses administered

statewise_vaccination = new_data.groupby('State')['Total Individuals Vaccinated'].sum().to_frame('Total Individuals Vaccinated')
statewise_vaccination_to_plot = statewise_vaccination.copy()
statewise_vaccination['Total Individuals Vaccinated'] = statewise_vaccination['Total Individuals Vaccinated'].apply(lambda x: '{:,.0f}'.format(x))
statewise_vaccination
# Out:
#                                          Total Individuals Vaccinated
# State
# Andaman and Nicobar Islands                                 8,102,125
# Andhra Pradesh                                            564,591,113
# Arunachal Pradesh                                          21,081,557
# Assam                                                     239,769,091
# Bihar                                                     660,847,900
# Chandigarh                                                 19,731,496
# Chhattisgarh                                              435,309,241
# Dadra and Nagar Haveli and Daman and Diu                   11,358,600
# Delhi                                                     305,737,211
# Goa                                                        32,114,784
# Gujarat                                                 1,078,260,544
# Haryana                                                   363,754,675
# ...

# %%
statewise_vaccination['Total Individuals Vaccinated'] = statewise_vaccination['Total Individuals Vaccinated'].str.replace(',', '').astype(int)

statewise_vaccination_to_plot.plot(kind='bar', figsize=(17,10))
plt.ylabel('Number of people vaccinated')
plt.show()

# %% [markdown]
# STATEWISE FIRST DOSE ADMINISTERED

# %%
# Statewise First Dose Administered Data

statewise_vaccination_dose1 = new_data[['State','First Dose Administered']].groupby('State').sum()
statewise_vaccination_dose1['First Dose Administered'] = statewise_vaccination_dose1['First Dose Administered'].apply(lambda x: '{:,.0f}'.format(x))
statewise_vaccination_dose1
# Out:
#                                          First Dose Administered
# State
# Andaman and Nicobar Islands                           39,279,350
# Andhra Pradesh                                     1,255,714,341
# Arunachal Pradesh                                     71,858,476
# Assam                                                608,453,722
# Bihar                                              1,493,356,374
# Chandigarh                                            67,556,601
# Chhattisgarh                                         818,856,398
# Dadra and Nagar Haveli and Daman and Diu              60,257,475
# Delhi                                                651,001,885
# Goa                                                   98,844,864
# Gujarat                                            2,154,499,505
# Haryana                                              778,651,848
# Himachal Pradesh                                     339,147,500
# ...

# %% [markdown]
# STATEWISE SECOND DOSE ADMINISTERED

# %%
# Statewise Second Dose Administered

statewise_vaccination_dose2 = new_data[['State','Second Dose Administered']].groupby('State').sum()
statewise_vaccination_dose2['Second Dose Administered'] = statewise_vaccination_dose2['Second Dose Administered'].apply(lambda x: '{:,.0f}'.format(x))
statewise_vaccination_dose2
# Out:
#                                          Second Dose Administered
# State
# Andaman and Nicobar Islands                            42,162,958
# Andhra Pradesh                                        394,748,421
# Arunachal Pradesh                                      47,863,143
# Assam                                                 166,719,618
# Bihar                                                 306,721,397
# Chandigarh                                             47,524,561
# Chhattisgarh                                          208,051,226
# Dadra and Nagar Haveli and Daman and Diu               41,582,031
# Delhi                                                 225,206,561
# Goa                                                    52,129,000
# Gujarat                                               636,349,202
# Haryana                                               194,586,884
# Himachal Pradesh                                      109,769,408
# ...

# %% [markdown]
# GRAPH SHOWING STATEWISE MALE AND FEMALE DOSES ADMINISTERED

# %%
# Graph showing Both Male and Female Statewise Dose Administered Date

group_Data = data.groupby("State")[['Male (Doses Administered)' , 'Female (Doses Administered)']].sum()
group_Data[['Male (Doses Administered)' , 'Female (Doses Administered)']].plot(kind = "bar")
plt.xlabel("State")
plt.ylabel("Number rof Doses Administered")
plt.title("Male and Female Doses Administered statewise")
plt.legend(["Male" , "Female"])
plt.xticks(rotation = 90)
plt.show()
