# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("covid_vaccine_statewise.csv")

# %%
data.head(5)
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
data.tail(5)
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# 7840                      NaN                       NaN
# 7841                      NaN                       NaN
# 7842                      NaN                       NaN
# 7843                      NaN                       NaN
# 7844                      NaN                       NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 7840                        NaN                          NaN
# ...

# %%
data.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
data.shape
# Out:
# (7845, 24)

# %%
data.dtypes
# Out:
# Updated On                              object
# State                                   object
# Total Doses Administered               float64
# Sessions                               float64
#  Sites                                 float64
# First Dose Administered                float64
# Second Dose Administered               float64
# Male (Doses Administered)              float64
# Female (Doses Administered)            float64
# Transgender (Doses Administered)       float64
#  Covaxin (Doses Administered)          float64
# CoviShield (Doses Administered)        float64
# Sputnik V (Doses Administered)         float64
# AEFI                                   float64
# 18-44 Years (Doses Administered)       float64
# 45-60 Years (Doses Administered)       float64
# 60+ Years (Doses Administered)         float64
# 18-44 Years(Individuals Vaccinated)    float64
# 45-60 Years(Individuals Vaccinated)    float64
# 60+ Years(Individuals Vaccinated)      float64
# ...

# %%
data["State"].unique()
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
data.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
data.fillna(value=0, inplace=True)

# %%
data.isnull().sum()
# Out:
# Updated On                             0
# State                                  0
# Total Doses Administered               0
# Sessions                               0
#  Sites                                 0
# First Dose Administered                0
# Second Dose Administered               0
# Male (Doses Administered)              0
# Female (Doses Administered)            0
# Transgender (Doses Administered)       0
#  Covaxin (Doses Administered)          0
# CoviShield (Doses Administered)        0
# Sputnik V (Doses Administered)         0
# AEFI                                   0
# 18-44 Years (Doses Administered)       0
# 45-60 Years (Doses Administered)       0
# 60+ Years (Doses Administered)         0
# 18-44 Years(Individuals Vaccinated)    0
# 45-60 Years(Individuals Vaccinated)    0
# 60+ Years(Individuals Vaccinated)      0
# Male(Individuals Vaccinated)           0
# Female(Individuals Vaccinated)         0
# Transgender(Individuals Vaccinated)    0
# ...

# %%
data['Total Doses Administered'] = data['Total Doses Administered'].astype('int64')
data['Sessions'] = data['Sessions'].astype('int64')
data['First Dose Administered'] = data['First Dose Administered'].astype('int64')
data['Second Dose Administered'] = data['Second Dose Administered'].astype('int64')
data['Male (Doses Administered)'] = data['Male (Doses Administered)'].astype('int64')
data['Female (Doses Administered)'] = data['Female (Doses Administered)'].astype('int64')
data['Transgender (Doses Administered)'] = data['Transgender (Doses Administered)'].astype('int64')
data[' Covaxin (Doses Administered)'] = data[' Covaxin (Doses Administered)'].astype('int64')
data['CoviShield (Doses Administered)'] = data['CoviShield (Doses Administered)'].astype('int64')
data['Sputnik V (Doses Administered)'] = data['Sputnik V (Doses Administered)'].astype('int64')
data['AEFI'] = data['AEFI'].astype('int64')
data['18-44 Years (Doses Administered)'] = data['18-44 Years (Doses Administered)'].astype('int64')
data['45-60 Years (Doses Administered)'] = data['45-60 Years (Doses Administered)'].astype('int64')
data['60+ Years (Doses Administered)'] = data['60+ Years (Doses Administered)'].astype('int64')
data['18-44 Years(Individuals Vaccinated)'] = data['18-44 Years(Individuals Vaccinated)'].astype('int64')
data['45-60 Years(Individuals Vaccinated)'] = data['45-60 Years(Individuals Vaccinated)'].astype('int64')
data['60+ Years(Individuals Vaccinated)'] = data['60+ Years(Individuals Vaccinated)'].astype('int64')
data['Male(Individuals Vaccinated)'] = data['Male(Individuals Vaccinated)'].astype('int64')
data['Female(Individuals Vaccinated)'] = data['Female(Individuals Vaccinated)'].astype('int64')
data['Transgender(Individuals Vaccinated)'] = data['Transgender(Individuals Vaccinated)'].astype('int64')
data['Total Individuals Vaccinated'] = data['Total Individuals Vaccinated'].astype('int64')

# %%
data.dtypes
# Out:
# Updated On                              object
# State                                   object
# Total Doses Administered                 int64
# Sessions                                 int64
#  Sites                                 float64
# First Dose Administered                  int64
# Second Dose Administered                 int64
# Male (Doses Administered)                int64
# Female (Doses Administered)              int64
# Transgender (Doses Administered)         int64
#  Covaxin (Doses Administered)            int64
# CoviShield (Doses Administered)          int64
# Sputnik V (Doses Administered)           int64
# AEFI                                     int64
# 18-44 Years (Doses Administered)         int64
# 45-60 Years (Doses Administered)         int64
# 60+ Years (Doses Administered)           int64
# 18-44 Years(Individuals Vaccinated)      int64
# 45-60 Years(Individuals Vaccinated)      int64
# 60+ Years(Individuals Vaccinated)        int64
# ...

# %%
date = data['Updated On'].str.split('/', expand=True)
date
# Out:
#        0   1     2
# 0     16  01  2021
# 1     17  01  2021
# 2     18  01  2021
# 3     19  01  2021
# 4     20  01  2021
# ...   ..  ..   ...
# 7840  11  08  2021
# 7841  12  08  2021
# 7842  13  08  2021
# 7843  14  08  2021
# 7844  15  08  2021
#
# [7845 rows x 3 columns]

# %%
data['day'] = date[0]
data['month'] = date[1]
data['year'] = date[2]

data['day'] = pd.to_numeric(data['day'])
data['month'] = pd.to_numeric(data['month'])
data['year'] = pd.to_numeric(data['year'])

data['Updated On'] = pd.to_datetime(data['Updated On'])
data.rename(columns = {'Updated On' : 'Vaccine_date'}, inplace = True)

data.head()
# Out:
# C:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
data.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.845000e+03  7.845000e+03   7845.000000
# mean               8.925819e+06  4.655521e+05   2217.688719
# std                3.695473e+07  1.885710e+06   7181.404758
# min                0.000000e+00  0.000000e+00      0.000000
# 25%                1.129780e+05  4.913000e+03     63.000000
# 50%                7.445650e+05  3.634500e+04    541.000000
# 75%                6.344469e+06  3.263560e+05   1642.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.845000e+03              7.845000e+03
# mean              7.202710e+06              1.723109e+06
# std               2.954714e+07              7.467353e+06
# min               0.000000e+00              0.000000e+00
# 25%               9.479600e+04              8.724000e+03
# 50%               6.170910e+05              1.205330e+05
# ...

# %%
number_of_males_vaccinated = data['Male(Individuals Vaccinated)'].sum()
print('Total Number of Males Vaccinated : ',number_of_males_vaccinated )
# Out:
# Total Number of Males Vaccinated :  7138698858

# %%
number_of_females_vaccinated = data['Female(Individuals Vaccinated)'].sum()
print('Total Number of Females Vaccinated : ',number_of_females_vaccinated )
# Out:
# Total Number of Females Vaccinated :  6321628736

# %%
plt.pie([number_of_males_vaccinated, number_of_females_vaccinated], labels = ['Males','Females'],
        colors = ['blue','pink'], autopct = '%0.0f%%', startangle = 90, radius = 2)
plt.legend(loc='best',shadow=True,fontsize=11)
plt.show()

# %%
new_data = data

# %%
statewise_vaccination = new_data.groupby('State')['Total Individuals Vaccinated'].sum().to_frame('Total Individuals Vaccinated')
statewise_vaccination
# Out:
#                                           Total Individuals Vaccinated
# State
# Andaman and Nicobar Islands                                    8102125
# Andhra Pradesh                                               564591113
# Arunachal Pradesh                                             21081557
# Assam                                                        239769091
# Bihar                                                        660847900
# Chandigarh                                                    19731496
# Chhattisgarh                                                 435309241
# Dadra and Nagar Haveli and Daman and Diu                      11358600
# Delhi                                                        305737211
# Goa                                                           32114784
# Gujarat                                                     1078260544
# Haryana                                                      363754675
# ...

# %%
statewise_vaccination.plot(kind='bar', figsize=(17,10))
plt.ylabel('Number of people vaccinated')
plt.show()

# %%
statewise_vaccination_dose1 = new_data[['State','First Dose Administered']].groupby('State').sum()
statewise_vaccination_dose1
# Out:
#                                           First Dose Administered
# State
# Andaman and Nicobar Islands                              16425854
# Andhra Pradesh                                         1232860845
# Arunachal Pradesh                                        49004980
# Assam                                                   585600226
# Bihar                                                  1470502878
# Chandigarh                                               44703105
# Chhattisgarh                                            796002902
# Dadra and Nagar Haveli and Daman and Diu                 33595063
# Delhi                                                   624339473
# Goa                                                      75991368
# Gujarat                                                2131646009
# Haryana                                                 755798352
# Himachal Pradesh                                        316294004
# ...

# %%
statewise_vaccination_dose2 = new_data[['State','Second Dose Administered']].groupby('State').sum()
statewise_vaccination_dose2
# Out:
#                                           Second Dose Administered
# State
# Andaman and Nicobar Islands                                4118554
# Andhra Pradesh                                           358817595
# Arunachal Pradesh                                         11932317
# Assam                                                    130788792
# Bihar                                                    270790571
# Chandigarh                                                11593735
# Chhattisgarh                                             172120400
# Dadra and Nagar Haveli and Daman and Diu                   4594416
# Delhi                                                    188218946
# Goa                                                       16198174
# Gujarat                                                  600418376
# Haryana                                                  158656058
# Himachal Pradesh                                          73838582
# ...
